# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./img_storage/DSC_0265.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) ## BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

detector=cv2.CascadeClassifier('./haarcascade_frontalface_default.xml')

faces = detector.detectMultiScale(gray, 1.1, 4)

for(x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

plt.imshow(img)

# %%
from deepface import DeepFace ## pip install deepface

# %%
predictions =  DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  6.00it/s]
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  5.94it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 3.756376112939996e-09,
#    'disgust': 6.051997997968365e-14,
#    'fear': 9.323343312661603e-10,
#    'happy': 99.7048556804657,
#    'sad': 8.515657512475627e-07,
#    'surprise': 2.905165885636052e-06,
#    'neutral': 0.2951483242213726},
#   'dominant_emotion': 'happy',
#   'region': {'x': 1066, 'y': 1098, 'w': 978, 'h': 978},
#   'age': 32,
#   'gender': {'Woman': 99.30877089500427, 'Man': 0.6912310607731342},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 97.80907604802562,
#    'indian': 1.2644464726086226,
#    'black': 0.009998654887152673,
#    'white': 0.10625850511816205,
#    'middle eastern': 0.004154217589986372,
#    'latino hispanic': 0.8060691907786358},
#   'dominant_race': 'asian'},
#  {'emotion': {'angry': 97.2597661900799,
#    'disgust': 9.539353413545422e-06,
#    'fear': 2.644577493419946,
#    'happy': 0.015154129881664528,
#    'sad': 0.07421251782290425,
#    'surprise': 0.0004863984815954411,
#    'neutral': 0.005782151531204213},
#   'dominant_emotion': 'angry',
#   'region': {'x': 1098, 'y': 2512, 'w': 61, 'h': 61},
#   'age': 26,
#   'gender': {'Woman': 4.407165572047234, 'Man': 95.5928385257721},
#   'dominant_gender': 'Man',
#   'race': {'asian': 8.498383313417435,
#    'indian': 0.7095221895724535,
#    'black': 0.5291576497256756,
#    'white': 75.11048913002014,
#    'middle eastern': 7.121714949607849,
#    'latino hispanic': 8.030737191438675},
#   'dominant_race': 'white'}]

# %%
type(predictions)
# Out:
# list

# %%
predictions = predictions[0]

# %%
predictions['dominant_emotion']
# Out:
# 'happy'
